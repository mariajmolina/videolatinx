# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects

# %%
# HLS origin prior knowledge and experience
# Fraction of HLS agreed
    
# The weather affects my day-to-day activities.
q1 = 0.65

# I am interested in pursuing a career in weather forecasting or computer modeling for weather prediction.
q2 = 0.23

#I have a career in weather forecasting or computer modeling for weather prediction.
q3 = 0.19

#I have learned about weather forecasting from the weather segment on the news. 
q4 = 0.47

#I have watched a documentary, television show, or video about weather forecasting.
q5 = 0.54

#I am interested in weather forecasting.
q6 = 0.66

#I have taken a class on weather forecasting.
q7 = 0.68

#I think mountains can affect the weather and weather forecasting.
q8 = 0.72

#I grew up in a mountainous area. 
q9 = 0.49

#None of these statements apply to me.
q10 = 0.00

# %%
fig = plt.figure(figsize=(8.,8.))

plt.suptitle('HLS Prior Knowledge\nand Experience', x=0.475, y=0.975)

#-----------------------%

ax1 = fig.add_axes([0.12, 0.0, 0.775, 0.05])

ax1.set_title('The weather affects my day-to-day activities.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax1.barh([0], [q1], 0.5, color='darkgoldenrod')
ln2 = ax1.barh([0], [1.0-q1], 0.5, left=q1, color='wheat')

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)

ax1.get_xaxis().set_ticks([])
ax1.get_yaxis().set_ticks([])

ax1.annotate(str(round(q1*100))+'%', xy=(0.0, 0.02), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax1.annotate(str(round((1-q1)*100))+'%', xy=(0.875, 0.02), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#----

ax1.annotate('% of participants agreed the\nstatement applied to them', 
             xy=(0.0, 0.925), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=12)

ax1.annotate('% of participants disagreed the\n        statement applied to them', 
             xy=(0.625, 0.925), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=12)

#-----------------------%

ax2 = fig.add_axes([0.12, 0.1, 0.775, 0.05])

ax2.set_title(
    'I am interested in pursuing a career in weather forecasting or computer modeling \nfor weather prediction.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax2.barh([0], [q2], 0.5, color='darkgoldenrod')
ln2 = ax2.barh([0], [1.0-q2], 0.5, left=q2, color='wheat')

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)

ax2.get_xaxis().set_ticks([])
ax2.get_yaxis().set_ticks([])

ax2.annotate(str(round(q2*100))+'%', xy=(0.0, 0.12), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax2.annotate(str(round((1-q2)*100))+'%', xy=(0.875, 0.12), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax3 = fig.add_axes([0.12, 0.225, 0.775, 0.05])

ax3.set_title('I have a career in weather forecasting or computer modeling for weather prediction.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax3.barh([0], [q3], 0.5, color='darkgoldenrod')
ln2 = ax3.barh([0], [1.0-q3], 0.5, left=q3, color='wheat')

ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)

ax3.get_xaxis().set_ticks([])
ax3.get_yaxis().set_ticks([])

ax3.annotate(str(round(q3*100))+'%', xy=(0.0, 0.245), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax3.annotate(str(round((1-q3)*100))+'%', xy=(0.875, 0.245), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax4 = fig.add_axes([0.12, 0.325, 0.775, 0.05])

ax4.set_title('I have learned about weather forecasting from the weather segment on the news.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax4.barh([0], [q4], 0.5, color='darkgoldenrod')
ln2 = ax4.barh([0], [1.0-q4], 0.5, left=q4, color='wheat')

ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['left'].set_visible(False)

ax4.get_xaxis().set_ticks([])
ax4.get_yaxis().set_ticks([])

ax4.annotate(str(round(q4*100))+'%', xy=(0.0, 0.345), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax4.annotate(str(round((1-q4)*100))+'%', xy=(0.875, 0.345), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax5 = fig.add_axes([0.12, 0.425, 0.775, 0.05])

ax5.set_title('I have watched a documentary, television show, or video about weather forecasting.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax5.barh([0], [q5], 0.5, color='darkgoldenrod')
ln2 = ax5.barh([0], [1.0-q5], 0.5, left=q5, color='wheat')

ax5.spines['top'].set_visible(False)
ax5.spines['right'].set_visible(False)
ax5.spines['bottom'].set_visible(False)
ax5.spines['left'].set_visible(False)

ax5.get_xaxis().set_ticks([])
ax5.get_yaxis().set_ticks([])

ax5.annotate(str(round(q5*100))+'%', xy=(0.0, 0.445), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax5.annotate(str(round((1-q5)*100))+'%', xy=(0.875, 0.445), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax6 = fig.add_axes([0.12, 0.525, 0.775, 0.05])

ax6.set_title('I am interested in weather forecasting.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax6.barh([0], [q6], 0.5, color='darkgoldenrod')
ln2 = ax6.barh([0], [1.0-q6], 0.5, left=q6, color='wheat')

ax6.spines['top'].set_visible(False)
ax6.spines['right'].set_visible(False)
ax6.spines['bottom'].set_visible(False)
ax6.spines['left'].set_visible(False)

ax6.get_xaxis().set_ticks([])
ax6.get_yaxis().set_ticks([])

ax6.annotate(str(round(q6*100))+'%', xy=(0.0, 0.545), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax6.annotate(str(round((1-q6)*100))+'%', xy=(0.875, 0.545), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax7 = fig.add_axes([0.12, 0.625, 0.775, 0.05])

ax7.set_title('I have taken a class on weather forecasting.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax7.barh([0], [q7], 0.5, color='darkgoldenrod')
ln2 = ax7.barh([0], [1.0-q7], 0.5, left=q7, color='wheat')

ax7.spines['top'].set_visible(False)
ax7.spines['right'].set_visible(False)
ax7.spines['bottom'].set_visible(False)
ax7.spines['left'].set_visible(False)

ax7.get_xaxis().set_ticks([])
ax7.get_yaxis().set_ticks([])

ax7.annotate(str(round(q7*100))+'%', xy=(0.0, 0.645), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax7.annotate(str(round((1-q7)*100))+'%', xy=(0.875, 0.645), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax8 = fig.add_axes([0.12, 0.725, 0.775, 0.05])

ax8.set_title('I think mountains can affect the weather and weather forecasting.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax8.barh([0], [q8], 0.5, color='darkgoldenrod')
ln2 = ax8.barh([0], [1.0-q8], 0.5, left=q8, color='wheat')

ax8.spines['top'].set_visible(False)
ax8.spines['right'].set_visible(False)
ax8.spines['bottom'].set_visible(False)
ax8.spines['left'].set_visible(False)

ax8.get_xaxis().set_ticks([])
ax8.get_yaxis().set_ticks([])

ax8.annotate(str(round(q8*100))+'%', xy=(0.0, 0.745), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax8.annotate(str(round((1-q8)*100))+'%', xy=(0.875, 0.745), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

ax9 = fig.add_axes([0.12, 0.825, 0.775, 0.05])

ax9.set_title('I grew up in a mountainous area.',
              loc='left', x= -0.1, fontsize=12)

ln1 = ax9.barh([0], [q9], 0.5, color='darkgoldenrod')
ln2 = ax9.barh([0], [1.0-q9], 0.5, left=q9, color='wheat')

ax9.spines['top'].set_visible(False)
ax9.spines['right'].set_visible(False)
ax9.spines['bottom'].set_visible(False)
ax9.spines['left'].set_visible(False)

ax9.get_xaxis().set_ticks([])
ax9.get_yaxis().set_ticks([])

ax9.annotate(str(round(q9*100))+'%', xy=(0.0, 0.845), xycoords='figure fraction',
             fontweight='bold', c='darkgoldenrod', fontsize=28)

ax9.annotate(str(round((1-q9)*100))+'%', xy=(0.875, 0.845), xycoords='figure fraction',
             fontweight='bold', c='wheat', fontsize=28)

#-----------------------%

plt.savefig(f"morales_jge_fig3.png", bbox_inches='tight', dpi=500)
plt.show()

#-----------------------%
